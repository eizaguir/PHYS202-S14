# %% [markdown]
# # Project Euler 17

# %%
ones = {0:'0',
        1:'3',
        2:'3',
        3:'5',
        4:'4',
        5:'4',
        6:'3',
        7:'5',
        8:'5',
        9:'4',
}

tens = {0:'0',
        10:'3',
        11:'6',
        12:'6',
        13:'8',
        14:'8',
        15:'7',
        16:'7',
        17:'9',
        18:'8',
        19:'8',
        20:'6',
        30:'6',
        40:'5',
        50:'5',
        60:'5',
        70:'7',
        80:'6',
        90:'6', 
}

hundreds = {100:'10',
            200:'10',
            300:'12',
            400:'11',
            500:'11',
            600:'10',
            700:'12',
            800:'12',
            900:'11',
}

total=0

#plug in number you want (inclusive)
for i in range(319):
    x = i+1
    if(x<10):
        num = ones[x]
        total = total + int(num)
    if(x>=10 and x<=20):
        num = tens[x]
        total = total + int(num)
    if(x>20 and x<30):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[20])
    if(x>=30 and x<40):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[30])
    if(x>=40 and x<50):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[40])
    if(x>=50 and x<60):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[50])
    if(x>=60 and x<70):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[60])
    if(x>=70 and x<80):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[70])
    if(x>=80 and x<90):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[80])
    if(x>=90 and x<100):
        remainder = x%10
        num = ones[remainder]
        total = total + int(num)
        total = total + int(tens[90])
    if(x>=100 and x<200):
        remainder = x%100
        num = ones[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[100])
    if(x>=200 and x<300):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[200])
    if(x>=300 and x<400):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[300])
    if(x>=400 and x<500):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[400])
    if(x>=500 and x<600):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[500])
    if(x>=600 and x<700):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[600])
    if(x>=700 and x<800):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[700])
    if(x>=800 and x<900):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[800])
    if(x>=900 and x<1000):
        remainder = x%100
        num = hundreds[remainder]
        total = total + int(num) + int (num)
        total = total + int(hundreds[900])
print total
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-98752aed9c37> in <module>()
#      96     if(x>=100 and x<200):
#      97         remainder = x%100
# ---> 98         num = ones[remainder]
#      99         total = total + int(num) + int (num)
#     100         total = total + int(hundreds[100])
#
# KeyError: 10

# %%
dict = {'Name': 'Zara', 'Age': 7, 'Class': 'First'};

print "dict['Name']: ", dict['Name'];
print "dict['Age']: ", dict['Age'];
# Out:
# dict['Name']:  Zara
# dict['Age']:  7
