# %%
from ipythonblocks import BlockGrid
# %pylab inline
import numpy as np
import random

BLUE = (0,0,255)
RED = (255,0,0)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['interactive', 'random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
def one_color(target_grid, color,grid):
    for row_number in range(target_grid.height):
        for column_number in range(target_grid.width):
            grid[row_number, column_number] = color

# %%
def UpdateGridColors(bluearr,redarr,grid,arr):
    one_color(grid,(200,200,200),grid)
    for i in bluearr:
        x, y = where(arr==i)
        a = int(x[0])
        b = int(y[0])
        grid[a,b] = BLUE
            
    for i in redarr:
        x, y = where(arr==i)
        a = int(x[0])
        b = int(y[0])
        grid[a,b] = RED

# %%
def CreateTwoColorArrays(Blues,Reds,size,grid,arr):
    total = Blues+Reds
    random_arr = np.array(random.sample(xrange(1,size+1),total))
    print "My random numbers are: %s"%random_arr
    BlueList = []
    RedList = []
    
    Blue = True
    for i in range(len(random_arr)):
        if len(BlueList) < Blues:
            BlueList.append(random_arr[i])

        else:
            RedList.append(random_arr[i])
            
    BlueArray = np.asarray(BlueList)
    RedArray = np.asarray(RedList)
            
    return BlueArray,RedArray

# %%
def getEmptySquares(blueArr,redArr,size):
    allcolorArr = numpy.concatenate([blueArr,redArr])
    emptyArr = np.array(range(1,size+1))
    for i in emptyArr:
        if i in allcolorArr:
            x = where(emptyArr==i)
            emptyArr = numpy.delete(emptyArr,x)
    
    
    return emptyArr

# %%
def determineHappiness(square,tolerance,grid,arr):
    x,y = findPosition(square,arr)
    xsize,ysize = grid.width,grid.height
    xsize-=1
    ysize-=1
    totalRed = 0
    totalBlue = 0
    
    if x > 0:
        if grid[x-1,y].red ==255:
            totalRed+=1
    if y > 0:
        if grid[x,y-1].red ==255:
            totalRed+=1
            
    if y < ysize:
        if grid[x,y+1].red==255:
            totalRed+=1

    if x < xsize:
        if grid[x+1,y].red==255:
            totalRed+=1
            
    if x < xsize and y < ysize:
        if grid[x+1,y+1].red==255:
            totalRed+=1
            
    if x < xsize and y > 0:
        if grid[x+1,y-1].red==255:
            totalRed+=1
        
    if x > 0 and y < ysize:
        if grid[x-1,y+1].red==255:
            totalRed+=1
        
    if x > 0 and y > 0:
        if grid[x-1,y-1].red==255:
            totalRed+=1
    
    if x > 0:
        if grid[x-1,y].blue==255:
            totalBlue+=1
        
    if y > 0:
        if grid[x,y-1].blue==255:
            totalBlue+=1
            
    if y < ysize:
        if grid[x,y+1].blue==255:
            totalBlue+=1
        
    if x < xsize:
        if grid[x+1,y].blue==255:
            totalBlue+=1
        
    if x < xsize and y < ysize:
        if grid[x+1,y+1].blue==255:
            totalBlue+=1
    if x < xsize and y > 0:
        if grid[x+1,y-1].blue==255:
            totalBlue+=1

    if x > 0 and y < ysize:
        if grid[x-1,y+1].blue==255:
            totalBlue+=1

    if x > 0 and y > 0:
        if grid[x-1,y-1].blue==255:
            totalBlue+=1
            
    
    totalSurrounding = 0
    
    if x==0 and y==0:
        totalSurrounding=3
    elif x==xsize and y==ysize:
        totalSurrounding=3
    elif x==0 and y==ysize:
        totalSurrounding=3
    elif y==0 and x==xsize:
        totalSurrounding=3
        
    elif x==0 or y==0 or y==ysize or x==xsize:
        totalSurrounding=5
    else:
        totalSurrounding=8
    
    rating = True
    
    if grid[x,y].red == 255:
        if totalBlue!=0:
            ratio = float(totalRed)/(totalBlue+totalRed)
            if ratio < tolerance:
                rating=False
            
    if grid[x,y].blue == 255:
        if totalRed!=0:
            ratio = float(totalBlue)/(totalRed+totalBlue)
            if ratio < tolerance:
                rating=False
        
    
    return rating

# %%
def findPosition(square,arr):
    x,y = where(arr==square)
    x = int(x)
    y = int(y)
    return x,y

# %%
def moveSquare(square,BlueArr,RedArr,EmptyArr,grid,arr,size):
    isRed=False
    x, y = findPosition(square,arr)
    if grid[x,y].red==255:
        isRed=True
    grid[x,y] = (200,200,200)
    
    
    
    randEmptySquare = EmptyArr[random.randint(0,len(EmptyArr)-1)]
    xrand, yrand = findPosition(randEmptySquare,arr)
    
    if isRed==False:
        grid[xrand,yrand].red=0
        grid[xrand,yrand].blue=255
        grid[xrand,yrand].green=0
    else:
        grid[xrand,yrand].red = 255
        grid[xrand,yrand].blue=0
        grid[xrand,yrand].green=0
    
    #grid.show()
    
    #Update EmptyArr, Red/BlueArr
    if isRed==False:
        NewBlueArr = np.delete(BlueArr,where(BlueArr==square))
        addArr = np.array([randEmptySquare])
        BlueArr = np.concatenate([NewBlueArr,addArr])
        BlueArr = np.sort(BlueArr)
        NewEmptyArr = np.delete(EmptyArr,where(EmptyArr==randEmptySquare))
        addArr = np.array([square])
        EmptyArr = np.concatenate([NewEmptyArr,addArr])
        
    else:
        NewRedArr = np.delete(RedArr,where(RedArr==square))
        addArr = np.array([randEmptySquare])
        RedArr = np.concatenate([NewRedArr,addArr])
        RedArr = np.sort(RedArr)
        NewEmptyArr = np.delete(EmptyArr,where(EmptyArr==randEmptySquare))
        addArr = np.array([square])
        EmptyArr = np.concatenate([NewEmptyArr,addArr])
        
        """ print "Blue Arr, Out: %s"%BlueArr
        print "Red Arr, Out: %s\n"%RedArr"""

    return BlueArr,RedArr,EmptyArr

# %%
from IPython.html import widgets # Widget definitions
from IPython.display import display
from IPython.html.widgets import interact, interactive
from IPython.display import clear_output
import time
    
def function(Empty=.02,RedBlueRatio=.5,Tolerance=.625,sidelength=100):
    
    BLUE = (0,0,255)
    RED = (255,0,0)


    xsize = sidelength
    ysize = sidelength
    grid = BlockGrid(xsize, ysize, fill=(123, 234, 123))
    
    x,y = grid.shape
    size = x*y
    arr = np.arange(1, size+1).reshape(xsize, ysize)
    #Prompt User
    TotalEmpty = int(Empty*size)
    ColorSq=size-TotalEmpty
    Reds = int(RedBlueRatio*ColorSq)
    Blues = ColorSq-Reds
    """Blues = input("Please enter in the amount of Blues you want. (Max %s) "%size)
    if Blues>size:
        return "That is too many Blues, please try again."
    Reds = input("Please enter in the amount of Reds you want. (Max %s) "%(size-Blues))
    if Reds>(size-Blues): 
        return "That is too many Reds, please try again."
    
    print "Blues: %s. Reds: %s"%(Blues, Reds)"""
    
    BlueArr, RedArr = CreateTwoColorArrays(Blues,Reds,size,grid,arr)
    BlueArr = np.sort(BlueArr)
    RedArr = np.sort(RedArr)
    UpdateGridColors(BlueArr,RedArr,grid,arr)
    EmptyArr = getEmptySquares(BlueArr,RedArr,size)
    #print "Empty array = %s"%EmptyArr
    """Rounds = input("How many rounds would you like? ")
    Tolerance = input("What tolerance would you like? ")"""
    
    
    grid.show()
    Rounds=1*10**6
    for i in range(Rounds):
        clear_output()
        totalHappiness=0
        print "Round %s"%(i+1)
        moved=False
        #move squares
        allcolorArr = numpy.concatenate([BlueArr,RedArr])
        
        unHappyList = []
        for square in allcolorArr:
            
            if determineHappiness(square,Tolerance,grid,arr)==False:
                unHappyList.append(square)
        unHappyArr = np.asarray(unHappyList)
        x=0
        #print "AllColorArr Before moves= ",allcolorArr
        for square in unHappyArr:
            x+=1
            print "Made it to move square loop for the ", x ," time"
            x1,y1 = findPosition(square,arr)
            if (grid[x1,y1].red == 255) or (grid[x1,y1].blue == 255):
                if determineHappiness(square,Tolerance,grid,arr)==False:
                    BlueArr, RedArr, EmptyArr = moveSquare(square,BlueArr,RedArr,EmptyArr,grid,arr,size)
                    
        allcolorArr = numpy.concatenate([BlueArr,RedArr])
        #print "AllColorArr After moves= ",allcolorArr
                
        UpdateGridColors(BlueArr,RedArr,grid,arr)
        allcolorArr2 = numpy.concatenate([BlueArr,RedArr])
        #check Happiness    
        for square in allcolorArr2:
            x1,y1 = findPosition(square,arr)
            if (grid[x1,y1].red == 255) or (grid[x1,y1].blue == 255):
                if determineHappiness(square,Tolerance,grid,arr)==False:
                    moved=True
                else:
                    totalHappiness+=1
    
        
        #print "BLue arr",len(BlueArr)
        #print "Red arr",len(RedArr)
        #print "total Happiness",totalHappiness
        percentHappiness = (float(totalHappiness)/(len(BlueArr) + len(RedArr))*100)
        print "Percent Happiness",percentHappiness
        grid.show()
        if moved==False:
            print "Everyone is satisfied!"
            break
            
        if i==range(Rounds):
            print "Failed."
        
        #time.sleep(1)
        
    
interact(function,Empty=(0,1,.01),RedBlueRatio=(0,1,.1),Tolerance=(0,1,.1),sidelength=(1,100,1))
# Out:
# Round 27
# Made it to move square loop for the
#  1  time
# Made it to move square loop for the  2  time
# Made it to move square loop for the  3  time
# Made it to move square loop for the  4  time
# Made it to move square loop for the  5  time
# Made it to move square loop for the  6  time
# Made it to move square loop for the  7  time
# Made it to move square loop for the  8  time
# Made it to move square loop for the  9  time
# Made it to move square loop for the  10  time
# Made it to move square loop for the  11  time
# Made it to move square loop for the  12  time
# Made it to move square loop for the  13  time
# Made it to move square loop for the  14  time
# Made it to move square loop for the  15  time
# Made it to move square loop for the  16  time
# Made it to move square loop for the  17  time
# Made it to move square loop for the  18  time
# Made it to move square loop for the  19  time
# Made it to move square loop for the  20  time
# Made it to move square loop for the  21  time
# Made it to move square loop for the  22  time
# Made it to move square loop for the  23  time
# Made it to move square loop for the  24  time
# Made it to move square loop for the  25  time
# Made it to move square loop for the  26  time
# Made it to move square loop for the  27  time
# Made it to move square loop for the  28  time
# Made it to move square loop for the  29  time
# Made it to move square loop for the  30  time
# Made it to move square loop for the  31  time
# Made it to move square loop for the  32  time
# Made it to move square loop for the  33  time
# Made it to move square loop for the  34  time
# Made it to move square loop for the  35  time
# Made it to move square loop for the  36  time
# Made it to move square loop for the  37  time
# Made it to move square loop for the  38  time
# Made it to move square loop for the  39  time
# Made it to move square loop for the  40  time
# Made it to move square loop for the  41  time
# Made it to move square loop for the  42  time
# Made it to move square loop for the  43  time
# Made it to move square loop for the  44  time
# Made it to move square loop for the  45  time
# Made it to move square loop for the  46  time
# Made it to move square loop for the  47  time
# Made it to move square loop for the  48  time
# Made it to move square loop for the  49  time
# Made it to move square loop for the  50  time
# Made it to move square loop for the  51  time
# Made it to move square loop for the  52  time
# Made it to move square loop for the  53  time
# Made it to move square loop for the  54  time
# Made it to move square loop for the  55  time
# Made it to move square loop for the  56  time
# Made it to move square loop for the  57  time
# Made it to move square loop for the  58  time
# Made it to move square loop for the  59  time
# Made it to move square loop for the  60  time
# Made it to move square loop for the  61  time
# Made it to move square loop for the  62  time
# Made it to move square loop for the
#  63  time
# Made it to move square loop for the  64  time
# Made it to move square loop for the  65  time
# Made it to move square loop for the  66  time
# Made it to move square loop for the  67  time
# Made it to move square loop for the  68  time
# Made it to move square loop for the  69  time
# Made it to move square loop for the  70  time
# Made it to move square loop for the  71  time
# Made it to move square loop for the  72  time
# Made it to move square loop for the  73  time
# Made it to move square loop for the  74  time
# Made it to move square loop for the  75  time
# Made it to move square loop for the  76  time
# Made it to move square loop for the  77  time
# Made it to move square loop for the  78  time
# Made it to move square loop for the  79  time
# Made it to move square loop for the  80  time
# Made it to move square loop for the  81  time
# Made it to move square loop for the  82  time
# Made it to move square loop for the  83  time
# Made it to move square loop for the  84  time
# Made it to move square loop for the  85  time
# Made it to move square loop for the  86  time
# Made it to move square loop for the  87  time
# Made it to move square loop for the  88  time
# Made it to move square loop for the  89  time
# Made it to move square loop for the  90  time
# Made it to move square loop for the  91  time
# Made it to move square loop for the  92  time
# Made it to move square loop for the  93  time
# Made it to move square loop for the  94  time
# Made it to move square loop for the  95  time
# Made it to move square loop for the  96  time
# Made it to move square loop for the  97  time
# Made it to move square loop for the  98  time
# Made it to move square loop for the  99  time
# Made it to move square loop for the  100  time
# Made it to move square loop for the  101  time
# Made it to move square loop for the  102  time
# Made it to move square loop for the  103  time
# Made it to move square loop for the  104  time
# Made it to move square loop for the  105  time
# Made it to move square loop for the  106  time
# Made it to move square loop for the  107  time
# Made it to move square loop for the  108  time
# Made it to move square loop for the  109  time
# Made it to move square loop for the  110  time
# Made it to move square loop for the  111  time
# Made it to move square loop for the  112  time
# Made it to move square loop for the  113  time
# Made it to move square loop for the  114  time
# Made it to move square loop for the  115  time
# Made it to move square loop for the  116  time
# Made it to move square loop for the  117  time
# Made it to move square loop for the  118  time
# Made it to move square loop for the  119  time
# Made it to move square loop for the  120  time
# Made it to move square loop for the
#  121  time
# Made it to move square loop for the  122  time
# Made it to move square loop for the  123  time
# Made it to move square loop for the  124  time
# Made it to move square loop for the  125  time
# Made it to move square loop for the  126  time
# Made it to move square loop for the  127  time
# Made it to move square loop for the  128  time
# Made it to move square loop for the  129  time
# Made it to move square loop for the  130  time
# Made it to move square loop for the  131  time
# Made it to move square loop for the  132  time
# Made it to move square loop for the  133  time
# Made it to move square loop for the  134  time
# Made it to move square loop for the  135  time
# Made it to move square loop for the  136  time
# Made it to move square loop for the  137  time
# Made it to move square loop for the  138  time
# Made it to move square loop for the  139  time
# Made it to move square loop for the  140  time
# Made it to move square loop for the  141  time
# Made it to move square loop for the  142  time
# Made it to move square loop for the  143  time
# Made it to move square loop for the  144  time
# Made it to move square loop for the  145  time
# Made it to move square loop for the  146  time
# Made it to move square loop for the  147  time
# Made it to move square loop for the  148  time
# Made it to move square loop for the  149  time
# Made it to move square loop for the  150  time
# Made it to move square loop for the  151  time
# Made it to move square loop for the  152  time
# Made it to move square loop for the  153  time
# Made it to move square loop for the  154  time
# Made it to move square loop for the  155  time
# Made it to move square loop for the  156  time
# Made it to move square loop for the  157  time
# Made it to move square loop for the  158  time
# Made it to move square loop for the  159  time
# Made it to move square loop for the  160  time
# Made it to move square loop for the  161  time
# Made it to move square loop for the  162  time
# Made it to move square loop for the  163  time
# Made it to move square loop for the  164  time
# Made it to move square loop for the  165  time
# Made it to move square loop for the  166  time
# Made it to move square loop for the  167  time
# Made it to move square loop for the  168  time
# Made it to move square loop for the  169  time
# Made it to move square loop for the  170  time
# Made it to move square loop for the  171  time
# Made it to move square loop for the  172  time
# Made it to move square loop for the  173  time
# Made it to move square loop for the  174  time
# Made it to move square loop for the  175  time
# Made it to move square loop for the  176  time
# Made it to move square loop for the  177  time
# Made it to move square loop for the  178  time
# Made it to move square loop for the  179  time
# Made it to move square loop for the
#  180  time
# Made it to move square loop for the  181  time
# Made it to move square loop for the  182  time
# Made it to move square loop for the  183  time
# Made it to move square loop for the  184  time
# Made it to move square loop for the  185  time
# Made it to move square loop for the  186  time
# Made it to move square loop for the  187  time
# Made it to move square loop for the  188  time
# Made it to move square loop for the  189  time
# Made it to move square loop for the  190  time
# Made it to move square loop for the  191  time
# Made it to move square loop for the  192  time
# Made it to move square loop for the  193  time
# Made it to move square loop for the  194  time
# Made it to move square loop for the  195  time
# Made it to move square loop for the  196  time
# Made it to move square loop for the  197  time
# Made it to move square loop for the  198  time
# Made it to move square loop for the  199  time
# Made it to move square loop for the  200  time
# Made it to move square loop for the  201  time
# Made it to move square loop for the  202  time
# Made it to move square loop for the  203  time
# Made it to move square loop for the  204  time
# Made it to move square loop for the  205  time
# Made it to move square loop for the  206  time
# Made it to move square loop for the  207  time
# Made it to move square loop for the  208  time
# Made it to move square loop for the  209  time
# Made it to move square loop for the  210  time
# Made it to move square loop for the  211  time
# Made it to move square loop for the  212  time
# Made it to move square loop for the  213  time
# Made it to move square loop for the  214  time
# Made it to move square loop for the  215  time
# Made it to move square loop for the  216  time
# Made it to move square loop for the  217  time
# Made it to move square loop for the  218  time
# Made it to move square loop for the  219  time
# Made it to move square loop for the  220  time
# Made it to move square loop for the  221  time
# Made it to move square loop for the  222  time
# Made it to move square loop for the  223  time
# Made it to move square loop for the  224  time
# Made it to move square loop for the  225  time
# Made it to move square loop for the  226  time
# Made it to move square loop for the  227  time
# Made it to move square loop for the  228  time
# Made it to move square loop for the  229  time
# Made it to move square loop for the  230  time
# Made it to move square loop for the  231  time
# Made it to move square loop for the  232  time
# Made it to move square loop for the  233  time
# Made it to move square loop for the  234  time
# Made it to move square loop for the  235  time
# Made it to move square loop for the  236  time
# Made it to move square loop for the  237  time
# Made it to move square loop for the  238  time
# Made it to move square loop for the  239  time
# Made it to move square loop for the  240  time
# Made it to move square loop for the  241  time
# Made it to move square loop for the  242  time
# Made it to move square loop for the  243  time
# Made it to move square loop for the  244  time
# Made it to move square loop for the  245  time
# Made it to move square loop for the  246  time
# Made it to move square loop for the  247  time
# Made it to move square loop for the  248  time
# Made it to move square loop for the  249  time
# Made it to move square loop for the  250  time
# Made it to move square loop for the
#  251  time
# Made it to move square loop for the  252  time
# Made it to move square loop for the  253  time
# Made it to move square loop for the  254  time
# Made it to move square loop for the  255  time
# Made it to move square loop for the  256  time
# Made it to move square loop for the  257  time
# Made it to move square loop for the  258  time
# Made it to move square loop for the  259  time
# Made it to move square loop for the  260  time
# Made it to move square loop for the  261  time
# Made it to move square loop for the  262  time
# Made it to move square loop for the  263  time
# Made it to move square loop for the  264  time
# Made it to move square loop for the  265  time
# Made it to move square loop for the  266  time
# Made it to move square loop for the  267  time
# Made it to move square loop for the  268  time
# Made it to move square loop for the  269  time
# Made it to move square loop for the  270  time
# Made it to move square loop for the  271  time
# Made it to move square loop for the  272  time
# Made it to move square loop for the  273  time
# Made it to move square loop for the  274  time
# Made it to move square loop for the  275  time
# Made it to move square loop for the  276  time
# Made it to move square loop for the  277  time
# Made it to move square loop for the  278  time
# Made it to move square loop for the  279  time
# Made it to move square loop for the  280  time
# Made it to move square loop for the  281  time
# Made it to move square loop for the  282  time
# Made it to move square loop for the  283  time
# Made it to move square loop for the  284  time
# Made it to move square loop for the  285  time
# Made it to move square loop for the  286  time
# Made it to move square loop for the  287  time
# Made it to move square loop for the  288  time
# Made it to move square loop for the  289  time
# Made it to move square loop for the  290  time
# Made it to move square loop for the  291  time
# Made it to move square loop for the  292  time
# Made it to move square loop for the  293  time
# Made it to move square loop for the  294  time
# Made it to move square loop for the  295  time
# Made it to move square loop for the  296  time
# Made it to move square loop for the  297  time
# Made it to move square loop for the  298  time
# Made it to move square loop for the  299  time
# Made it to move square loop for the  300  time
# Made it to move square loop for the  301  time
# Made it to move square loop for the  302  time
# Made it to move square loop for the  303  time
# Made it to move square loop for the  304  time
# Made it to move square loop for the  305  time
# Made it to move square loop for the  306  time
# Made it to move square loop for the  307  time
# Made it to move square loop for the  308  time
# Made it to move square loop for the  309  time
# Made it to move square loop for the  310  time
# Made it to move square loop for the  311  time
# Made it to move square loop for the  312  time
# Made it to move square loop for the  313  time
# Made it to move square loop for the  314  time
# Made it to move square loop for the  315  time
# Made it to move square loop for the  316  time
# Made it to move square loop for the  317  time
# Made it to move square loop for the  318  time
# Made it to move square loop for the  319  time
# Made it to move square loop for the  320  time
# Made it to move square loop for the  321  time
# Made it to move square loop for the  322  time
# Made it to move square loop for the  323  time
# Made it to move square loop for the
#  324  time
# Made it to move square loop for the  325  time
# Made it to move square loop for the  326  time
# Made it to move square loop for the  327  time
# Made it to move square loop for the  328  time
# Made it to move square loop for the  329  time
# Made it to move square loop for the  330  time
# Made it to move square loop for the  331  time
# Made it to move square loop for the  332  time
# Made it to move square loop for the  333  time
# Made it to move square loop for the  334  time
# Made it to move square loop for the  335  time
# Made it to move square loop for the  336  time
# Made it to move square loop for the  337  time
# Made it to move square loop for the  338  time
# Made it to move square loop for the  339  time
# Made it to move square loop for the  340  time
# Made it to move square loop for the  341  time
# Made it to move square loop for the  342  time
# Made it to move square loop for the  343  time
# Made it to move square loop for the  344  time
# Made it to move square loop for the  345  time
# Made it to move square loop for the  346  time
# Made it to move square loop for the  347  time
# Made it to move square loop for the  348  time
# Made it to move square loop for the  349  time
# Made it to move square loop for the  350  time
# Made it to move square loop for the  351  time
# Made it to move square loop for the  352  time
# Made it to move square loop for the  353  time
# Made it to move square loop for the  354  time
# Made it to move square loop for the  355  time
# Made it to move square loop for the  356  time
# Made it to move square loop for the  357  time
# Made it to move square loop for the  358  time
# Made it to move square loop for the  359  time
# Made it to move square loop for the  360  time
# Made it to move square loop for the  361  time
# Made it to move square loop for the  362  time
# Made it to move square loop for the  363  time
# Made it to move square loop for the  364  time
# Made it to move square loop for the  365  time
# Made it to move square loop for the  366  time
# Made it to move square loop for the  367  time
# Made it to move square loop for the  368  time
# Made it to move square loop for the  369  time
# Made it to move square loop for the  370  time
# Made it to move square loop for the  371  time
# Made it to move square loop for the  372  time
# Made it to move square loop for the  373  time
# Made it to move square loop for the  374  time
# Made it to move square loop for the  375  time
# Made it to move square loop for the  376  time
# Made it to move square loop for the  377  time
# Made it to move square loop for the  378  time
# Made it to move square loop for the  379  time
# Made it to move square loop for the  380  time
# Made it to move square loop for the  381  time
# Made it to move square loop for the  382  time
# Made it to move square loop for the  383  time
# Made it to move square loop for the  384  time
# Made it to move square loop for the  385  time
# Made it to move square loop for the  386  time
# Made it to move square loop for the  387  time
# Made it to move square loop for the  388  time
# Made it to move square loop for the  389  time
# Made it to move square loop for the  390  time
# Made it to move square loop for the  391  time
# Made it to move square loop for the  392  time
# Made it to move square loop for the  393  time
# Made it to move square loop for the  394  time
# Made it to move square loop for the  395  time
# Made it to move square loop for the  396  time
# Made it to move square loop for the  397  time
# Made it to move square loop for the  398  time
# Made it to move square loop for the
#  399  time
# Made it to move square loop for the  400  time
# Made it to move square loop for the  401  time
# Made it to move square loop for the  402  time
# Made it to move square loop for the  403  time
# Made it to move square loop for the  404  time
# Made it to move square loop for the  405  time
# Made it to move square loop for the  406  time
# Made it to move square loop for the  407  time
# Made it to move square loop for the  408  time
# Made it to move square loop for the  409  time
# Made it to move square loop for the  410  time
# Made it to move square loop for the  411  time
# Made it to move square loop for the  412  time
# Made it to move square loop for the  413  time
# Made it to move square loop for the  414  time
# Made it to move square loop for the  415  time
# Made it to move square loop for the  416  time
# Made it to move square loop for the  417  time
# Made it to move square loop for the  418  time
# Made it to move square loop for the  419  time
# Made it to move square loop for the  420  time
# Made it to move square loop for the  421  time
# Made it to move square loop for the  422  time
# Made it to move square loop for the  423  time
# Made it to move square loop for the  424  time
# Made it to move square loop for the  425  time
# Made it to move square loop for the  426  time
# Made it to move square loop for the  427  time
# Made it to move square loop for the  428  time
# Made it to move square loop for the  429  time
# Made it to move square loop for the  430  time
# Made it to move square loop for the  431  time
# Made it to move square loop for the  432  time
# Made it to move square loop for the  433  time
# Made it to move square loop for the  434  time
# Made it to move square loop for the  435  time
# Made it to move square loop for the  436  time
# Made it to move square loop for the  437  time
# Made it to move square loop for the  438  time
# Made it to move square loop for the  439  time
# Made it to move square loop for the  440  time
# Made it to move square loop for the  441  time
# Made it to move square loop for the  442  time
# Made it to move square loop for the  443  time
# Made it to move square loop for the  444  time
# Made it to move square loop for the  445  time
# Made it to move square loop for the  446  time
# Made it to move square loop for the  447  time
# Made it to move square loop for the  448  time
# Made it to move square loop for the  449  time
# Made it to move square loop for the  450  time
# Made it to move square loop for the  451  time
# Made it to move square loop for the  452  time
# Made it to move square loop for the  453  time
# Made it to move square loop for the  454  time
# Made it to move square loop for the  455  time
# Made it to move square loop for the  456  time
# Made it to move square loop for the  457  time
# Made it to move square loop for the  458  time
# Made it to move square loop for the  459  time
# Made it to move square loop for the  460  time
# Made it to move square loop for the  461  time
# Made it to move square loop for the  462  time
# Made it to move square loop for the  463  time
# Made it to move square loop for the  464  time
# Made it to move square loop for the  465  time
# Made it to move square loop for the  466  time
# Made it to move square loop for the  467  time
# Made it to move square loop for the  468  time
# Made it to move square loop for the  469  time
# Made it to move square loop for the  470  time
# Made it to move square loop for the  471  time
# Made it to move square loop for the  472  time
# Made it to move square loop for the
#  473  time
# Made it to move square loop for the  474  time
# Made it to move square loop for the  475  time
# Made it to move square loop for the  476  time
# Made it to move square loop for the  477  time
# Made it to move square loop for the  478  time
# Made it to move square loop for the  479  time
# Made it to move square loop for the  480  time
# Made it to move square loop for the  481  time
# Made it to move square loop for the  482  time
# Made it to move square loop for the  483  time
# Made it to move square loop for the  484  time
# Made it to move square loop for the  485  time
# Made it to move square loop for the  486  time
# Made it to move square loop for the  487  time
# Made it to move square loop for the  488  time
# Made it to move square loop for the  489  time
# Made it to move square loop for the  490  time
# Made it to move square loop for the  491  time
# Made it to move square loop for the  492  time
# Made it to move square loop for the  493  time
# Made it to move square loop for the  494  time
# Made it to move square loop for the  495  time
# Made it to move square loop for the  496  time
# Made it to move square loop for the  497  time
# Made it to move square loop for the  498  time
# Made it to move square loop for the  499  time
# Made it to move square loop for the  500  time
# Made it to move square loop for the  501  time
# Made it to move square loop for the  502  time
# Made it to move square loop for the  503  time
# Made it to move square loop for the  504  time
# Made it to move square loop for the  505  time
# Made it to move square loop for the  506  time
# Made it to move square loop for the  507  time
# Made it to move square loop for the  508  time
# Made it to move square loop for the  509  time
# Made it to move square loop for the  510  time
# Made it to move square loop for the  511  time
# Made it to move square loop for the  512  time
# Made it to move square loop for the  513  time
# Made it to move square loop for the  514  time
# Made it to move square loop for the  515  time
# Made it to move square loop for the  516  time
# Made it to move square loop for the  517  time
# Made it to move square loop for the  518  time
# Made it to move square loop for the  519  time
# Made it to move square loop for the  520  time
# Made it to move square loop for the  521  time
# Made it to move square loop for the  522  time
# Made it to move square loop for the  523  time
# Made it to move square loop for the  524  time
# Made it to move square loop for the  525  time
# Made it to move square loop for the  526  time
# Made it to move square loop for the  527  time
# Made it to move square loop for the  528  time
# Made it to move square loop for the  529  time
# Made it to move square loop for the  530  time
# Made it to move square loop for the  531  time
# Made it to move square loop for the  532  time
# Made it to move square loop for the  533  time
# Made it to move square loop for the  534  time
# Made it to move square loop for the  535  time
# Made it to move square loop for the  536  time
# Made it to move square loop for the  537  time
# Made it to move square loop for the  538  time
# Made it to move square loop for the  539  time
# Made it to move square loop for the  540  time
# Made it to move square loop for the  541  time
# Made it to move square loop for the  542  time
# Made it to move square loop for the
#  543  time
# Made it to move square loop for the  544  time
# Made it to move square loop for the  545  time
# Made it to move square loop for the  546  time
# Made it to move square loop for the  547  time
# Made it to move square loop for the  548  time
# Made it to move square loop for the  549  time
# Made it to move square loop for the  550  time
# Made it to move square loop for the  551  time
# Made it to move square loop for the  552  time
# Made it to move square loop for the  553  time
# Made it to move square loop for the  554  time
# Made it to move square loop for the  555  time
# Made it to move square loop for the  556  time
# Made it to move square loop for the  557  time
# Made it to move square loop for the  558  time
# Made it to move square loop for the  559  time
# Made it to move square loop for the  560  time
# Made it to move square loop for the  561  time
# Made it to move square loop for the  562  time
# Made it to move square loop for the  563  time
# Made it to move square loop for the  564  time
# Made it to move square loop for the  565  time
# Made it to move square loop for the  566  time
# Made it to move square loop for the  567  time
# Made it to move square loop for the  568  time
# Made it to move square loop for the  569  time
# Made it to move square loop for the  570  time
# Made it to move square loop for the  571  time
# Made it to move square loop for the  572  time
# Made it to move square loop for the  573  time
# Made it to move square loop for the  574  time
# Made it to move square loop for the  575  time
# Made it to move square loop for the  576  time
# Made it to move square loop for the  577  time
# Made it to move square loop for the  578  time
# Made it to move square loop for the  579  time
# Made it to move square loop for the  580  time
# Made it to move square loop for the  581  time
# Made it to move square loop for the  582  time
# Made it to move square loop for the  583  time
# Made it to move square loop for the  584  time
# Made it to move square loop for the  585  time
# Made it to move square loop for the  586  time
# Made it to move square loop for the  587  time
# Made it to move square loop for the  588  time
# Made it to move square loop for the  589  time
# Made it to move square loop for the  590  time
# Made it to move square loop for the  591  time
# Made it to move square loop for the  592  time
# Made it to move square loop for the  593  time
# Made it to move square loop for the  594  time
# Made it to move square loop for the  595  time
# Made it to move square loop for the  596  time
# Made it to move square loop for the  597  time
# Made it to move square loop for the  598  time
# Made it to move square loop for the  599  time
# Made it to move square loop for the  600  time
# Made it to move square loop for the  601  time
# Made it to move square loop for the  602  time
# Made it to move square loop for the  603  time
# Made it to move square loop for the  604  time
# Made it to move square loop for the  605  time
# Made it to move square loop for the
#  606  time
# Made it to move square loop for the  607  time
# Made it to move square loop for the  608  time
# Made it to move square loop for the  609  time
# Made it to move square loop for the  610  time
# Made it to move square loop for the  611  time
# Made it to move square loop for the  612  time
# Made it to move square loop for the  613  time
# Made it to move square loop for the  614  time
# Made it to move square loop for the  615  time
# Made it to move square loop for the  616  time
# Made it to move square loop for the  617  time
# Made it to move square loop for the  618  time
# Made it to move square loop for the  619  time
# Made it to move square loop for the  620  time
# Made it to move square loop for the  621  time
# Made it to move square loop for the  622  time
# Made it to move square loop for the  623  time
# Made it to move square loop for the  624  time
# Made it to move square loop for the  625  time
# Made it to move square loop for the  626  time
# Made it to move square loop for the  627  time
# Made it to move square loop for the  628  time
# Made it to move square loop for the  629  time
# Made it to move square loop for the  630  time
# Made it to move square loop for the  631  time
# Made it to move square loop for the  632  time
# Made it to move square loop for the  633  time
# Made it to move square loop for the  634  time
# Made it to move square loop for the  635  time
# Made it to move square loop for the  636  time
# Made it to move square loop for the  637  time
# Made it to move square loop for the  638  time
# Made it to move square loop for the  639  time
# Made it to move square loop for the  640  time
# Made it to move square loop for the  641  time
# Made it to move square loop for the  642  time
# Made it to move square loop for the  643  time
# Made it to move square loop for the  644  time
# Made it to move square loop for the  645  time
# Made it to move square loop for the  646  time
# Made it to move square loop for the  647  time
# Made it to move square loop for the  648  time
# Made it to move square loop for the  649  time
# Made it to move square loop for the  650  time
# Made it to move square loop for the  651  time
# Made it to move square loop for the  652  time
# Made it to move square loop for the  653  time
# Made it to move square loop for the  654  time
# Made it to move square loop for the  655  time
# Made it to move square loop for the  656  time
# Made it to move square loop for the  657  time
# Made it to move square loop for the  658  time
# Made it to move square loop for the  659  time
# Made it to move square loop for the  660  time
# Made it to move square loop for the  661  time
# Made it to move square loop for the  662  time
# Made it to move square loop for the  663  time
# Made it to move square loop for the  664  time
# Made it to move square loop for the  665  time
# Made it to move square loop for the  666  time
# Made it to move square loop for the  667  time
# Made it to move square loop for the  668  time
# Made it to move square loop for the  669  time
# Made it to move square loop for the  670  time
# Made it to move square loop for the  671  time
# Made it to move square loop for the  672  time
# Made it to move square loop for the
#  673  time
# Made it to move square loop for the  674  time
# Made it to move square loop for the  675  time
# Made it to move square loop for the  676  time
# Made it to move square loop for the  677  time
# Made it to move square loop for the  678  time
# Made it to move square loop for the  679  time
# Made it to move square loop for the  680  time
# Made it to move square loop for the  681  time
# Made it to move square loop for the  682  time
# Made it to move square loop for the  683  time
# Made it to move square loop for the  684  time
# Made it to move square loop for the  685  time
# Made it to move square loop for the  686  time
# Made it to move square loop for the  687  time
# Made it to move square loop for the  688  time
# Made it to move square loop for the  689  time
# Made it to move square loop for the  690  time
# Made it to move square loop for the  691  time
# Made it to move square loop for the  692  time
# Made it to move square loop for the  693  time
# Made it to move square loop for the  694  time
# Made it to move square loop for the  695  time
# Made it to move square loop for the  696  time
# Made it to move square loop for the  697  time
# Made it to move square loop for the  698  time
# Made it to move square loop for the  699  time
# Made it to move square loop for the  700  time
# Made it to move square loop for the  701  time
# Made it to move square loop for the  702  time
# Made it to move square loop for the  703  time
# Made it to move square loop for the  704  time
# Made it to move square loop for the  705  time
# Made it to move square loop for the  706  time
# Made it to move square loop for the  707  time
# Made it to move square loop for the  708  time
# Made it to move square loop for the  709  time
# Made it to move square loop for the  710  time
# Made it to move square loop for the  711  time
# Made it to move square loop for the  712  time
# Made it to move square loop for the  713  time
# Made it to move square loop for the  714  time
# Made it to move square loop for the  715  time
# Made it to move square loop for the  716  time
# Made it to move square loop for the  717  time
# Made it to move square loop for the  718  time
# Made it to move square loop for the  719  time
# Made it to move square loop for the  720  time
# Made it to move square loop for the  721  time
# Made it to move square loop for the  722  time
# Made it to move square loop for the  723  time
# Made it to move square loop for the  724  time
# Made it to move square loop for the  725  time
# Made it to move square loop for the  726  time
# Made it to move square loop for the  727  time
# Made it to move square loop for the  728  time
# Made it to move square loop for the  729  time
# Made it to move square loop for the  730  time
# Made it to move square loop for the  731  time
# Made it to move square loop for the  732  time
# Made it to move square loop for the  733  time
# Made it to move square loop for the  734  time
# Made it to move square loop for the  735  time
# Made it to move square loop for the  736  time
# Made it to move square loop for the  737  time
# Made it to move square loop for the  738  time
# Made it to move square loop for the
#  739  time
# Made it to move square loop for the  740  time
# Made it to move square loop for the  741  time
# Made it to move square loop for the  742  time
# Made it to move square loop for the  743  time
# Made it to move square loop for the  744  time
# Made it to move square loop for the  745  time
# Made it to move square loop for the  746  time
# Made it to move square loop for the  747  time
# Made it to move square loop for the  748  time
# Made it to move square loop for the  749  time
# Made it to move square loop for the  750  time
# Made it to move square loop for the  751  time
# Made it to move square loop for the  752  time
# Made it to move square loop for the  753  time
# Made it to move square loop for the  754  time
# Made it to move square loop for the  755  time
# Made it to move square loop for the  756  time
# Made it to move square loop for the  757  time
# Made it to move square loop for the  758  time
# Made it to move square loop for the  759  time
# Made it to move square loop for the  760  time
# Made it to move square loop for the  761  time
# Made it to move square loop for the  762  time
# Made it to move square loop for the  763  time
# Made it to move square loop for the  764  time
# Made it to move square loop for the  765  time
# Made it to move square loop for the  766  time
# Made it to move square loop for the  767  time
# Made it to move square loop for the  768  time
# Made it to move square loop for the  769  time
# Made it to move square loop for the  770  time
# Made it to move square loop for the  771  time
# Made it to move square loop for the  772  time
# Made it to move square loop for the  773  time
# Made it to move square loop for the  774  time
# Made it to move square loop for the  775  time
# Made it to move square loop for the  776  time
# Made it to move square loop for the  777  time
# Made it to move square loop for the  778  time
# Made it to move square loop for the  779  time
# Made it to move square loop for the  780  time
# Made it to move square loop for the  781  time
# Made it to move square loop for the  782  time
# Made it to move square loop for the  783  time
# Made it to move square loop for the  784  time
# Made it to move square loop for the  785  time
# Made it to move square loop for the  786  time
# Made it to move square loop for the  787  time
# Made it to move square loop for the  788  time
# Made it to move square loop for the  789  time
# Made it to move square loop for the  790  time
# Made it to move square loop for the  791  time
# Made it to move square loop for the  792  time
# Made it to move square loop for the  793  time
# Made it to move square loop for the  794  time
# Made it to move square loop for the  795  time
# Made it to move square loop for the  796  time
# Made it to move square loop for the  797  time
# Made it to move square loop for the  798  time
# Made it to move square loop for the  799  time
# Made it to move square loop for the  800  time
# Made it to move square loop for the  801  time
# Made it to move square loop for the  802  time
# Made it to move square loop for the  803  time
# Made it to move square loop for the  804  time
# Made it to move square loop for the  805  time
# Made it to move square loop for the  806  time
# Made it to move square loop for the  807  time
# Made it to move square loop for the  808  time
# Made it to move square loop for the  809  time
# Made it to move square loop for the
